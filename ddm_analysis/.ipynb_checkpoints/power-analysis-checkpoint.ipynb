# %%
import hddm
from patsy import dmatrix  # for generation of (regression) design matrices
import numpy as np         # for basic matrix operations
from pandas import Series  # to manipulate data-frames generated by hddm
# Out:
# /home/jasongong/anaconda3/lib/python3.7/site-packages/IPython/parallel.py:13: ShimWarning: The `IPython.parallel` package has been deprecated since IPython 4.0. You should import from ipyparallel instead.
#   "You should import from ipyparallel instead.", ShimWarning)

# %%
n_subjects = 100
trials_per_level = 20 # and per stimulus

# %%
level0 = {'v':.0, 'a':2.8, 't':.4, 'sv':0.05, 'z':.5, 'sz':0, 'st':0.2}
level1 = {'v':.1, 'a':2.8, 't':.4, 'sv':0.05, 'z':.5, 'sz':0, 'st':0.2}
level2 = {'v':-0.1, 'a':2.8, 't':.4, 'sv':0.05, 'z':.5, 'sz':0, 'st':0.2}
level3 = {'v':.2, 'a':2.8, 't':.4, 'sv':0.05, 'z':.5, 'sz':0, 'st':0.2}
level4 = {'v':.3, 'a':2.8, 't':.4, 'sv':0.05, 'z':.5, 'sz':0, 'st':0.2}

# %%
#import Pool
from multiprocessing import Pool
#Define a worker — a function which will be executed in parallel
def gen_worker(x):
    np.random.seed(x)
    sim_data, sim_params = hddm.generate.gen_rand_data({'level0': level0,
                                             'level1': level1,
                                             'level2': level2,
                                             'level3': level3,
                                             'level4': level4},
                                             size=trials_per_level,
                                             subjs=n_subjects)
    return sim_data

num_processors = 4
#Create a pool of processors
p=Pool(processes = num_processors)

#get them to work in parallel
gen_data = p.map(gen_worker,[i for i in range(200)])
# Out:
# Process ForkPoolWorker-13:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-bb19f6a34069> in <module>
#      18
#      19 #get them to work in parallel
# ---> 20 gen_data = p.map(gen_worker,[i for i in range(200)])
#
# ~/anaconda3/lib/python3.7/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     266         in a list that is returned.
#     267         '''
# --> 268         return self._map_async(func, iterable, mapstar, chunksize).get()
#     269
#     270     def starmap(self, func, iterable, chunksize=None):
#
# ~/anaconda3/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# ~/anaconda3/lib/python3.7/multiprocessing/pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:
# Process ForkPoolWorker-15:
# Traceback (most recent call last):
#   File "/home/jasongong/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/jasongong/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/jasongong/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/jasongong/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/jasongong/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-45-bb19f6a34069>", line 12, in gen_worker
#     subjs=n_subjects)
#   File "/home/jasongong/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-16:
#   File "/home/jasongong/anaconda3/lib/python3.7/site-packages/hddm/generate.py", line 422, in gen_rand_data
#     bounds=bounds, **kwargs)
#   File "/home/jasongong/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/jasongong/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# Traceback (most recent call last):
#   File "<ipython-input-45-bb19f6a34069>", line 12, in gen_worker
#     subjs=n_subjects)
#   File "/home/jasongong/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/jasongong/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/jasongong/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/jasongong/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/jasongong/anaconda3/lib/python3.7/site-packages/kabuki/generate.py", line 176, in gen_rand_data
#     samples_from_dist = gen_func(size=size, **params_cur)
#   File "/home/jasongong/anaconda3/lib/python3.7/site-packages/hddm/generate.py", line 422, in gen_rand_data
#     bounds=bounds, **kwargs)
#   File "<ipython-input-45-bb19f6a34069>", line 12, in gen_worker
#     subjs=n_subjects)
#   File "/home/jasongong/anaconda3/lib/python3.7/site-packages/kabuki/generate.py", line 176, in gen_rand_data
#     samples_from_dist = gen_func(size=size, **params_cur)
#   File "/home/jasongong/anaconda3/lib/python3.7/site-packages/hddm/generate.py", line 194, in gen_rts
#     size, range_[0], range_[1], dt)
#   File "/home/jasongong/anaconda3/lib/python3.7/site-packages/hddm/generate.py", line 422, in gen_rand_data
#     bounds=bounds, **kwargs)
#   File "wfpt.pyx", line 347, in wfpt.gen_rts_from_cdf
#   File "/home/jasongong/anaconda3/lib/python3.7/site-packages/kabuki/generate.py", line 176, in gen_rand_data
#     samples_from_dist = gen_func(size=size, **params_cur)
#   File "<__array_function__ internals>", line 2, in searchsorted
#   File "/home/jasongong/anaconda3/lib/python3.7/site-packages/hddm/generate.py", line 194, in gen_rts
#     size, range_[0], range_[1], dt)
# KeyboardInterrupt
#   File "/home/jasongong/anaconda3/lib/python3.7/site-packages/hddm/generate.py", line 194, in gen_rts
#     size, range_[0], range_[1], dt)
# Process ForkPoolWorker-14:
#   File "wfpt.pyx", line 347, in wfpt.gen_rts_from_cdf
#   File "wfpt.pyx", line 347, in wfpt.gen_rts_from_cdf
#   File "<__array_function__ internals>", line 2, in searchsorted
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "<__array_function__ internals>", line 2, in searchsorted
#   File "/home/jasongong/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/home/jasongong/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/jasongong/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/jasongong/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-45-bb19f6a34069>", line 12, in gen_worker
#     subjs=n_subjects)
#   File "/home/jasongong/anaconda3/lib/python3.7/site-packages/hddm/generate.py", line 422, in gen_rand_data
#     bounds=bounds, **kwargs)
#   File "/home/jasongong/anaconda3/lib/python3.7/site-packages/kabuki/generate.py", line 176, in gen_rand_data
#     samples_from_dist = gen_func(size=size, **params_cur)
#   File "/home/jasongong/anaconda3/lib/python3.7/site-packages/hddm/generate.py", line 194, in gen_rts
#     size, range_[0], range_[1], dt)
#   File "wfpt.pyx", line 347, in wfpt.gen_rts_from_cdf
#   File "<__array_function__ internals>", line 2, in searchsorted
# KeyboardInterrupt

# %%
#import Pool
from multiprocessing import Pool
#Define a worker — a function which will be executed in parallel
def worker(x):
    m = hddm.HDDM(gen_data[x], depends_on={'v': 'condition'})
    m.find_starting_values()
    m.sample(1000, burn=20)
    return m

num_processors = 4
#Create a pool of processors
p=Pool(processes = num_processors)

#get them to work in parallel
output = p.map(worker,[i for i in range(200)])
# Out:
#  [                  1%                  ] 16 of 1000 complete in 23.5 secHalting at iteration  15  of  1000
# Halting at iteration  15  of  1000
# Halting at iteration  15  of  1000
# Halting at iteration  14  of  1000
# Could not generate output statistics for v_subj(level3).58
# Could not generate output statistics for v_subj(level1).39
# Could not generate output statistics for v_subj(level3).52
# Could not generate output statistics for v_subj(level1).37
# Could not generate output statistics for v_subj(level1).60
# Could not generate output statistics for v_subj(level2).2
# Could not generate output statistics for v_subj(level0).16
# Could not generate output statistics for v_subj(level2).1
# Could not generate output statistics for v_subj(level1).40
# Could not generate output statistics for v_subj(level3).59
# Could not generate output statistics for v_subj(level3).46
# Could not generate output statistics for v_subj(level2).1
# Could not generate output statistics for v_subj(level1).62
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-a3b882147d23> in <module>
#      13
#      14 #get them to work in parallel
# ---> 15 output = p.map(worker,[i for i in range(200)])
#
# ~/anaconda3/lib/python3.7/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     266         in a list that is returned.
#     267         '''
# --> 268         return self._map_async(func, iterable, mapstar, chunksize).get()
#     269
#     270     def starmap(self, func, iterable, chunksize=None):
#
# ~/anaconda3/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# ~/anaconda3/lib/python3.7/multiprocessing/pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:
# Could not generate output statistics for v_subj(level1).38
# Could not generate output statistics for v_subj(level0).48
# Could not generate output statistics for v_subj(level1).39
# Could not generate output statistics for v_subj(level0).57
# Could not generate output statistics for v_subj(level2).70
# Could not generate output statistics for v_subj(level0).47
# Could not generate output statistics for v_subj(level1).61
# Could not generate output statistics for v_subj(level1).60
# Could not generate output statistics for v_subj(level2).18
# Could not generate output statistics for v_subj(level0).46
# Could not generate output statistics for v_subj(level1).23
# Could not generate output statistics for v_subj(level2).17
# Could not generate output statistics for v_subj(level1).64
# Could not generate output statistics for v_subj(level1).63
# Could not generate output statistics for t_subj.80
# Could not generate output statistics for v_subj(level1).22
# Could not generate output statistics for v_subj(level1).62
# Could not generate output statistics for v_subj(level3).47
# Could not generate output statistics for v_subj(level2).14
# Could not generate output statistics for t_subj.64
# Could not generate output statistics for v_subj(level2).17
# Could not generate output statistics for v_subj(level3).50
# Could not generate output statistics for v_subj(level3).48
# Could not generate output statistics for v_subj(level3).55
# Could not generate output statistics for v_subj(level3).86
# Could not generate output statistics for v_subj(level4).3
# Could not generate output statistics for v_subj(level1).6
# Could not generate output statistics for v_subj(level0).14
# Could not generate output statistics for v_subj(level3).47
# Could not generate output statistics for v_subj(level3).87
# Could not generate output statistics for v_subj(level0).57
# Could not generate output statistics for v_subj(level1).68
# Could not generate output statistics for v_subj(level1).7
# Could not generate output statistics for v_subj(level2).0
# Could not generate output statistics for v_subj(level3).79
# Could not generate output statistics for v_subj(level3).80
# Could not generate output statistics for v_subj(level1).8
# Could not generate output statistics for v_subj(level1).78
# Could not generate output statistics for v_subj(level2).1
# Could not generate output statistics for t_subj.63
# Could not generate output statistics for v_subj(level1).86
# Could not generate output statistics for v_subj(level3).82
# Could not generate output statistics for a_subj.98
# Could not generate output statistics for v_subj(level1).8
# Could not generate output statistics for v_subj(level3).49
# Could not generate output statistics for v_subj(level1).9
# Could not generate output statistics for v_subj(level4).6
# Could not generate output statistics for v_subj(level3).86
# Could not generate output statistics for v_subj(level3).46
# Could not generate output statistics for v_subj(level2).2
# Could not generate output statistics for v_subj(level3).48
# Could not generate output statistics for v_subj(level1).36
# Could not generate output statistics for v_subj(level1).7
# Could not generate output statistics for v_subj(level4).99
# Could not generate output statistics for v_subj(level1).63
# Could not generate output statistics for v_subj(level0).17
# Could not generate output statistics for t_subj.42
# Could not generate output statistics for v_subj(level2).9
# Could not generate output statistics for v_subj(level1).75
# Could not generate output statistics for t
# Could not generate output statistics for v_subj(level1).88
# Could not generate output statistics for v_subj(level1).64
# Could not generate output statistics for v_subj(level4).23
# Could not generate output statistics for v_subj(level4).22
# Could not generate output statistics for v_subj(level2).10
# Could not generate output statistics for v_subj(level2).64
# Could not generate output statistics for v_subj(level2).69
# Could not generate output statistics for v_subj(level4).7
# Could not generate output statistics for a_subj.55
# Could not generate output statistics for v_subj(level4).6
# Could not generate output statistics for v_subj(level3).46
# Could not generate output statistics for v_subj(level4).29
# Could not generate output statistics for t_subj.66
# Could not generate output statistics for t_subj.46
# Could not generate output statistics for v_subj(level2).1
# Could not generate output statistics for t_subj.82
# Could not generate output statistics for v_subj(level0).38
# Could not generate output statistics for t_subj.66
# Could not generate output statistics for t_subj.68
# Could not generate output statistics for v_subj(level0).24
# Could not generate output statistics for v_subj(level3).45
# Could not generate output statistics for t_subj.78
# Could not generate output statistics for v_subj(level1).8
# Could not generate output statistics for v_subj(level3).58
# Could not generate output statistics for a_subj.15
# Could not generate output statistics for v_subj(level4).8
# Could not generate output statistics for v_subj(level1).67
# Could not generate output statistics for t_subj.47
# Could not generate output statistics for v_subj(level0).39
# Could not generate output statistics for v_subj(level4).92
# Could not generate output statistics for t_subj.81
# Could not generate output statistics for t_subj.15
# Could not generate output statistics for v_subj(level0).39
# Could not generate output statistics for v_subj(level2).77
# Could not generate output statistics for t_subj.65
# Could not generate output statistics for t_subj.65
# Could not generate output statistics for v_subj(level2).59
# Could not generate output statistics for v_subj(level1).9
# Could not generate output statistics for v_subj(level2).70
# Could not generate output statistics for v_subj(level4).8
# Could not generate output statistics for v_subj(level3).43
# Could not generate output statistics for t_subj.43
# Could not generate output statistics for v_subj(level3).48
# Could not generate output statistics for v_subj(level1).12
# Could not generate output statistics for v_subj(level0).42
# Could not generate output statistics for v_subj(level1).57
# Could not generate output statistics for v_subj(level0).40
# Could not generate output statistics for v_subj(level1).95
# Could not generate output statistics for v_subj(level3).57
# Could not generate output statistics for v_subj(level1).84
# Could not generate output statistics for v_subj(level1).85
# Could not generate output statistics for v_subj(level0).25
# Could not generate output statistics for v_subj(level3).99
# Could not generate output statistics for v_subj(level1).72
# Could not generate output statistics for v_subj(level3).44
# Could not generate output statistics for v_subj(level4).7
# Could not generate output statistics for t_subj.42
# Could not generate output statistics for t_subj.44
# Could not generate output statistics for v_subj(level1).19
# Could not generate output statistics for t_subj.63
# Could not generate output statistics for v_subj(level2).15
# Could not generate output statistics for v_subj(level1).38
# Could not generate output statistics for v_subj(level3).53
# Could not generate output statistics for v_subj(level0).30
# Could not generate output statistics for t_subj.62
# Could not generate output statistics for v_subj(level1).8
# Could not generate output statistics for v_subj(level4).7
# Could not generate output statistics for t_subj.43
# Could not generate output statistics for v_subj(level0).44
# Could not generate output statistics for a_subj.74
# Could not generate output statistics for v_subj(level0).37
# Could not generate output statistics for v_subj(level3).98
# Could not generate output statistics for v_subj(level0).55
# Could not generate output statistics for v_subj(level2).5
# Could not generate output statistics for t_subj.42
# Could not generate output statistics for v_subj(level1).39
# Could not generate output statistics for v_subj(level2).72
# Could not generate output statistics for t_subj.61
# Could not generate output statistics for v_subj(level4).0
# Could not generate output statistics for v_subj(level3).83
# Could not generate output statistics for t_subj.41
# Could not generate output statistics for v_subj(level0).27
# Could not generate output statistics for v_subj(level1).18
# Could not generate output statistics for v_subj(level3).81
# Could not generate output statistics for v_subj(level4).54
# Could not generate output statistics for v_subj(level3).97
# Could not generate output statistics for v_subj(level4).91
# Could not generate output statistics for a_subj.50
# Could not generate output statistics for v_subj(level0).52
# Could not generate output statistics for v_subj(level0).33
# Could not generate output statistics for a_subj.30
# Could not generate output statistics for v_subj(level1).67
# Could not generate output statistics for v_subj(level0).30
# Could not generate output statistics for v_subj(level3).51
# Could not generate output statistics for v_subj(level0).26
# Could not generate output statistics for t_subj.37
# Could not generate output statistics for v_subj(level1).65
# Could not generate output statistics for v_subj(level0).20
# Could not generate output statistics for v_subj(level3).52
# Could not generate output statistics for v_subj(level3).76
# Could not generate output statistics for v_subj(level3).77
# Could not generate output statistics for a_subj.24
# Could not generate output statistics for v_subj(level2).17
# Could not generate output statistics for v_subj(level1).41
# Could not generate output statistics for v_subj(level0).36
# Could not generate output statistics for v_subj(level3).76
# Could not generate output statistics for v_subj(level1).32
# Could not generate output statistics for t_subj.67
# Could not generate output statistics for v_subj(level1).65
# Could not generate output statistics for t_subj.14
# Could not generate output statistics for a_subj.84
# Could not generate output statistics for v_subj(level0).55
# Could not generate output statistics for v_subj(level2).16
# Could not generate output statistics for t_subj.38
# Could not generate output statistics for v_subj(level1).87
# Could not generate output statistics for v_subj(level4).1
# Could not generate output statistics for v_subj(level1).61
# Could not generate output statistics for v_subj(level1).6
# Could not generate output statistics for v_subj(level0).34
# Could not generate output statistics for v_subj(level1).59
# Could not generate output statistics for v_subj(level3).43
# Could not generate output statistics for v_subj(level0).25
# Could not generate output statistics for t_subj.65
# Could not generate output statistics for a_subj.8
# Could not generate output statistics for v_subj(level4).23
# Could not generate output statistics for v_subj(level4).10
# Could not generate output statistics for v_subj(level4).95
# Could not generate output statistics for v_subj(level1).35
# Could not generate output statistics for a_subj.10
# Could not generate output statistics for v_subj(level1).73
# Could not generate output statistics for v_subj(level1).66
# Could not generate output statistics for v_subj(level1).39
# Could not generate output statistics for v_subj(level4).24
# Could not generate output statistics for v_subj(level3).82
# Could not generate output statistics for v_subj(level4).78
# Could not generate output statistics for v_subj(level0).28
# Could not generate output statistics for t_subj.20
# Could not generate output statistics for v_subj(level1).81
# Could not generate output statistics for v_subj(level1).10
# Could not generate output statistics for a_subj.72
# Could not generate output statistics for v_subj(level3).85
# Could not generate output statistics for v_subj(level0).18
# Could not generate output statistics for v_subj(level4).75
# Could not generate output statistics for t_subj.66
# Could not generate output statistics for t_subj.21
# Could not generate output statistics for v_subj(level4).27
# Could not generate output statistics for a_subj.3
# Could not generate output statistics for v_subj(level2).12
# Could not generate output statistics for a_subj.81
# Could not generate output statistics for v_subj(level3).47
# Could not generate output statistics for v_subj(level2).4
# Could not generate output statistics for t_subj.2
# Could not generate output statistics for v_subj(level4).98
# Could not generate output statistics for v_subj(level0).43
# Could not generate output statistics for v_subj(level1).73
# Could not generate output statistics for t_subj.10
# Could not generate output statistics for v_subj(level4).77
# Could not generate output statistics for v_subj(level2).68
# Could not generate output statistics for v_subj(level1).69
# Could not generate output statistics for v_subj(level3).83
# Could not generate output statistics for v_subj(level4).15
# Could not generate output statistics for t_subj.45
# Could not generate output statistics for v_subj(level1).77
# Could not generate output statistics for v_subj(level3).79
# Could not generate output statistics for a_subj.76
# Could not generate output statistics for v_subj(level4).98
# Could not generate output statistics for a_subj.12
# Could not generate output statistics for v_subj(level1).61
# Could not generate output statistics for a_subj.15
# Could not generate output statistics for v_subj(level3).96
# Could not generate output statistics for v_subj(level0).27
# Could not generate output statistics for v_subj(level4).77
# Could not generate output statistics for v_subj(level1).65
# Could not generate output statistics for v_subj(level4).2
# Could not generate output statistics for v_subj(level4).92
# Could not generate output statistics for v_subj(level1).34
# Could not generate output statistics for v_subj(level0).32
# Could not generate output statistics for v_subj(level1).64
# Could not generate output statistics for v_subj(level4).76
# Could not generate output statistics for t_subj.46
# Could not generate output statistics for v_subj(level1).66
# Could not generate output statistics for v(level4)
# Could not generate output statistics for v_subj(level0).36
# Could not generate output statistics for v_subj(level1).66
# Could not generate output statistics for v_subj(level1).40
# Could not generate output statistics for v_subj(level1).35
# Could not generate output statistics for v_subj(level4).85
# Could not generate output statistics for v_subj(level3).44
# Could not generate output statistics for v_subj(level4).29
# Could not generate output statistics for v_subj(level4).92
# Could not generate output statistics for t_subj.67
# Could not generate output statistics for t_subj.28
# Could not generate output statistics for v_subj(level1).37
# Could not generate output statistics for v_subj(level1).79
# Could not generate output statistics for v_subj(level4).25
# Could not generate output statistics for v_subj(level3).51
# Could not generate output statistics for v_subj(level1).40
# Could not generate output statistics for v_subj(level2).4
# Could not generate output statistics for a_subj.73
# Could not generate output statistics for v_subj(level1).6
# Could not generate output statistics for v_subj(level1).38
# Could not generate output statistics for v_subj(level4).3
# Could not generate output statistics for v_subj(level0).41
# Could not generate output statistics for v_subj(level1).28
# Could not generate output statistics for v_subj(level4).70
# Could not generate output statistics for a_subj.9
# Could not generate output statistics for v_subj(level0).58
# Could not generate output statistics for t_subj.27
# Could not generate output statistics for t_subj.17
# Could not generate output statistics for v_subj(level3).55
# Could not generate output statistics for a_subj.5
# Could not generate output statistics for v_subj(level2).65
# Could not generate output statistics for t_subj.22
# Could not generate output statistics for a_subj.55
# Could not generate output statistics for v_subj(level1).36
# Could not generate output statistics for t_subj.9
# Could not generate output statistics for v_subj(level4).78
# Could not generate output statistics for a_subj.75
# Could not generate output statistics for a_subj.26
# Could not generate output statistics for a_subj.96
# Could not generate output statistics for a_subj.19
# Could not generate output statistics for v_subj(level1).82
# Could not generate output statistics for v_subj(level1).9
# Could not generate output statistics for v_subj(level4).16
# Could not generate output statistics for a_subj.24
# Could not generate output statistics for v_subj(level1).40
# Could not generate output statistics for v_subj(level4).70
# Could not generate output statistics for v_subj(level1).44
# Could not generate output statistics for v_subj(level1).9
# Could not generate output statistics for v_subj(level1).89
# Could not generate output statistics for v_subj(level4).93
# Could not generate output statistics for v_subj(level1).72
# Could not generate output statistics for v_subj(level4).94
# Could not generate output statistics for v_subj(level1).78
# Could not generate output statistics for v_subj(level1).11
# Could not generate output statistics for a_subj.11
# Could not generate output statistics for a_subj.14
# Could not generate output statistics for a_subj.89
# Could not generate output statistics for v_std
# Could not generate output statistics for v_subj(level1).41
# Could not generate output statistics for v_subj(level3).50
# Could not generate output statistics for v_subj(level1).7
# Could not generate output statistics for v_subj(level0).17
# Could not generate output statistics for v(level0)
# Could not generate output statistics for v_subj(level4).17
# Could not generate output statistics for a_subj.47
# Could not generate output statistics for v_subj(level0).17
# Could not generate output statistics for v_subj(level1).38
# Could not generate output statistics for v_subj(level0).29
# Could not generate output statistics for v_subj(level4).73
# Could not generate output statistics for t_subj.20
# Could not generate output statistics for v_subj(level1).43
# Could not generate output statistics for v_subj(level0).57
# Could not generate output statistics for t_subj.64
# Could not generate output statistics for t_subj.66
# Could not generate output statistics for v_subj(level0).39
# Could not generate output statistics for v_subj(level0).23
# Could not generate output statistics for v_subj(level1).20
# Could not generate output statistics for v_subj(level1).68
# Could not generate output statistics for v_subj(level1).33
# Could not generate output statistics for v_subj(level4).93
# Could not generate output statistics for v_subj(level1).97
# Could not generate output statistics for a_subj.22
# Could not generate output statistics for v_subj(level0).27
# Could not generate output statistics for v_subj(level0).40
# Could not generate output statistics for v_subj(level0).35
# Could not generate output statistics for v_subj(level2).98
# Could not generate output statistics for v_subj(level4).4
# Could not generate output statistics for v_subj(level3).49
# Could not generate output statistics for v_subj(level4).71
# Could not generate output statistics for v_subj(level4).81
# Could not generate output statistics for v_subj(level2).20
# Could not generate output statistics for v_subj(level4).23
# Could not generate output statistics for t_subj.21
# Could not generate output statistics for v_subj(level2).97
# Could not generate output statistics for v(level2)
# Could not generate output statistics for a_subj.46
# Could not generate output statistics for a_subj.49
# Could not generate output statistics for v_subj(level0).46
# Could not generate output statistics for v(level2)
# Could not generate output statistics for t_subj.39
# Could not generate output statistics for a_subj.4
# Could not generate output statistics for v_subj(level0).48
# Could not generate output statistics for v_subj(level0).57
# Could not generate output statistics for v_subj(level2).80
# Could not generate output statistics for v_subj(level4).77
# Could not generate output statistics for t_subj.44
# Could not generate output statistics for v_subj(level2).24
# Could not generate output statistics for a_subj.17
# Could not generate output statistics for v_subj(level0).23
# Could not generate output statistics for v_subj(level1).43
# Could not generate output statistics for v_subj(level1).15
# Could not generate output statistics for v_subj(level2).49
# Could not generate output statistics for v_subj(level1).10
# Could not generate output statistics for v_subj(level1).32
# Could not generate output statistics for a_subj.91
# Could not generate output statistics for v_subj(level2).92
# Could not generate output statistics for v_subj(level1).47
# Could not generate output statistics for v_subj(level3).50
# Could not generate output statistics for t
# Could not generate output statistics for a_subj.49
# Could not generate output statistics for v_subj(level1).98
# Could not generate output statistics for a_subj.57
# Could not generate output statistics for v_subj(level2).17
# Could not generate output statistics for a_subj.24
# Could not generate output statistics for t_subj.19
# Could not generate output statistics for v_subj(level2).22
# Could not generate output statistics for v_subj(level2).21
# Could not generate output statistics for v_subj(level2).75
# Could not generate output statistics for v_subj(level1).12
# Could not generate output statistics for v_subj(level2).48
# Could not generate output statistics for a_subj.33
# Could not generate output statistics for v_subj(level4).24
# Could not generate output statistics for v_subj(level1).45
# Could not generate output statistics for v_subj(level3).67
# Could not generate output statistics for a_subj.2
# Could not generate output statistics for v_subj(level0).88
# Could not generate output statistics for v_subj(level3).74
# Could not generate output statistics for v_subj(level4).5
# Could not generate output statistics for a_subj.7
# Could not generate output statistics for v_subj(level3).0
# Could not generate output statistics for v_subj(level3).0
# Could not generate output statistics for v_subj(level3).7
# Could not generate output statistics for v_subj(level1).37
# Could not generate output statistics for v_subj(level0).44
# Could not generate output statistics for v_subj(level1).42
# Could not generate output statistics for v_subj(level2).47
# Could not generate output statistics for v_subj(level0).63
# Could not generate output statistics for a_subj.5
# Could not generate output statistics for v(level0)
# Could not generate output statistics for v_subj(level3).78
# Could not generate output statistics for a_subj.30
# Could not generate output statistics for v_subj(level2).87
# Could not generate output statistics for v_subj(level0).28
# Could not generate output statistics for v_subj(level2).28
# Could not generate output statistics for v_subj(level0).56
# Could not generate output statistics for v_subj(level2).50
# Could not generate output statistics for v_subj(level3).6
# Could not generate output statistics for a_subj.49
# Could not generate output statistics for a_subj.90
# Could not generate output statistics for v_subj(level2).23
# Could not generate output statistics for a_subj.49
# Could not generate output statistics for t_subj.63
# Could not generate output statistics for a_subj.98
# Could not generate output statistics for v_subj(level2).69
# Could not generate output statistics for v_subj(level0).55
# Could not generate output statistics for a_subj.3
# Could not generate output statistics for v_subj(level4).76
# Could not generate output statistics for v_subj(level0).90
# Could not generate output statistics for v_subj(level4).93
# Could not generate output statistics for v_subj(level0).47
# Could not generate output statistics for v_subj(level0).59
# Could not generate output statistics for t_subj.19
# Could not generate output statistics for v_subj(level4).77
# Could not generate output statistics for t_subj.65
# Could not generate output statistics for v_subj(level2).51
# Could not generate output statistics for v_subj(level1).45
# Could not generate output statistics for v_subj(level1).14
# Could not generate output statistics for v_subj(level4).37
# Could not generate output statistics for v_subj(level1).31
# Could not generate output statistics for t_subj.67
# Could not generate output statistics for v_subj(level1).46
# Could not generate output statistics for v_subj(level2).78
# Could not generate output statistics for v_subj(level0).54
# Could not generate output statistics for v_subj(level1).97
# Could not generate output statistics for v_subj(level0).63
# Could not generate output statistics for v_subj(level0).29
# Could not generate output statistics for v_subj(level2).16
# Could not generate output statistics for v_subj(level2).27
# Could not generate output statistics for v_subj(level2).67
# Could not generate output statistics for v_subj(level2).58
# Could not generate output statistics for v_subj(level1).44
# Could not generate output statistics for v_subj(level0).50
# Could not generate output statistics for v_subj(level2).81
# Could not generate output statistics for v_subj(level3).69
# Could not generate output statistics for v_subj(level1).34
# Could not generate output statistics for v_subj(level2).61
# Could not generate output statistics for v_subj(level2).39
# Could not generate output statistics for v_subj(level2).82
# Could not generate output statistics for v_subj(level1).44
# Could not generate output statistics for v_subj(level3).68
# Could not generate output statistics for v_subj(level2).87
# Could not generate output statistics for v_subj(level0).97
# Could not generate output statistics for t_subj.39
# Could not generate output statistics for v_subj(level3).71
# Could not generate output statistics for v_subj(level3).68
# Could not generate output statistics for v_subj(level2).54
# Could not generate output statistics for v_subj(level3).2
# Could not generate output statistics for v_subj(level2).71
# Could not generate output statistics for v_subj(level0).49
# Could not generate output statistics for v_subj(level2).91
# Could not generate output statistics for v_subj(level2).97
# Could not generate output statistics for v_subj(level0).94
# Could not generate output statistics for v_subj(level2).27
# Could not generate output statistics for t_subj.83
# Could not generate output statistics for v_subj(level2).25
# Could not generate output statistics for a_subj.99
# Could not generate output statistics for v_subj(level3).66
# Could not generate output statistics for v_subj(level0).66
# Could not generate output statistics for a_subj.16
# Could not generate output statistics for v_subj(level2).47
# Could not generate output statistics for a_subj.8
# Could not generate output statistics for v_subj(level3).68
# Could not generate output statistics for v_subj(level3).67
# Could not generate output statistics for v_subj(level2).80
# Could not generate output statistics for v_subj(level2).94
# Could not generate output statistics for v_subj(level0).54
# Could not generate output statistics for v_subj(level2).91
# Could not generate output statistics for v_subj(level1).10
# Could not generate output statistics for v_subj(level0).53
# Could not generate output statistics for v_subj(level2).79
# Could not generate output statistics for v_subj(level0).46
# Could not generate output statistics for v_subj(level3).67
# Could not generate output statistics for v_subj(level4).92
# Could not generate output statistics for v_subj(level4).81
# Could not generate output statistics for v_subj(level2).21
# Could not generate output statistics for v_subj(level4).38
# Could not generate output statistics for t_subj.15
# Could not generate output statistics for v_subj(level2).55
# Could not generate output statistics for v_subj(level1).13
# Could not generate output statistics for v_subj(level0).91
# Could not generate output statistics for v_subj(level2).51
# Could not generate output statistics for v_subj(level1).12
# Could not generate output statistics for v_subj(level3).7
# Could not generate output statistics for v_subj(level2).99
# Could not generate output statistics for v_subj(level0).62
# Could not generate output statistics for v_subj(level3).65
# Could not generate output statistics for v_subj(level2).26
# Could not generate output statistics for a_subj.47
# Could not generate output statistics for v_subj(level2).44
# Could not generate output statistics for a_subj.27
# Could not generate output statistics for v_subj(level2).70
# Could not generate output statistics for v_subj(level4).87
# Could not generate output statistics for v_subj(level2).90
# Could not generate output statistics for a_subj.92
# Could not generate output statistics for t_subj.40
# Could not generate output statistics for v_subj(level3).67
# Could not generate output statistics for v_subj(level3).66
# Could not generate output statistics for v_subj(level3).65
# Could not generate output statistics for v_subj(level3).77
# Could not generate output statistics for v_subj(level2).72
# Could not generate output statistics for v_subj(level3).76
# Could not generate output statistics for v_subj(level3).1
# Could not generate output statistics for v_subj(level4).3
# Could not generate output statistics for v_subj(level2).92
# Could not generate output statistics for v_subj(level0).48
# Could not generate output statistics for a_subj.7
# Could not generate output statistics for v_subj(level0).93
# Could not generate output statistics for a_subj.20
# Could not generate output statistics for v_subj(level2).24
# Could not generate output statistics for a_subj.80
# Could not generate output statistics for v_subj(level3).68
# Could not generate output statistics for v_subj(level2).89
# Could not generate output statistics for v_subj(level3).5
# Could not generate output statistics for v_subj(level2).46
# Could not generate output statistics for v_subj(level0).60
# Could not generate output statistics for v_subj(level4).91
# Could not generate output statistics for v_subj(level3).1
# Could not generate output statistics for v_subj(level0).92
# Could not generate output statistics for v_subj(level3).71
# Could not generate output statistics for v_subj(level0).54
# Could not generate output statistics for v_subj(level4).2
# Could not generate output statistics for v_subj(level2).57
# Could not generate output statistics for v_subj(level4).41
# Could not generate output statistics for v_subj(level2).54
# Could not generate output statistics for a_subj.51
# Could not generate output statistics for v_subj(level0).56
# Could not generate output statistics for v_subj(level2).76
# Could not generate output statistics for v_subj(level0).54
# Could not generate output statistics for v_subj(level2).25
# Could not generate output statistics for v_subj(level4).5
# Could not generate output statistics for v_subj(level2).25
# Could not generate output statistics for v_subj(level2).56
# Could not generate output statistics for v_subj(level0).65
# Could not generate output statistics for v_subj(level4).7
# Could not generate output statistics for v_subj(level0).62
# Could not generate output statistics for v_subj(level3).66
# Could not generate output statistics for v_subj(level2).24
# Could not generate output statistics for v_subj(level4).2
# Could not generate output statistics for v_subj(level4).4
# Could not generate output statistics for v_subj(level2).40
# Could not generate output statistics for a_subj.85
# Could not generate output statistics for v_subj(level1).11
# Could not generate output statistics for v_subj(level2).77
# Could not generate output statistics for v_subj(level0).45
# Could not generate output statistics for v_subj(level3).77
# Could not generate output statistics for v_subj(level2).53
# Could not generate output statistics for v_subj(level4).3
# Could not generate output statistics for v_subj(level2).86
# Could not generate output statistics for t_subj.42
# Could not generate output statistics for v_subj(level2).19
# Could not generate output statistics for v_subj(level3).64
# Could not generate output statistics for v_subj(level0).52
# Could not generate output statistics for v_subj(level3).70
# Could not generate output statistics for a_subj.4
# Could not generate output statistics for a_subj.19
# Could not generate output statistics for v_subj(level0).62
# Could not generate output statistics for v_subj(level2).93
# Could not generate output statistics for a_subj.90
# Could not generate output statistics for v_subj(level0).56
# Could not generate output statistics for v_subj(level2).95
# Could not generate output statistics for v_subj(level3).58
# Could not generate output statistics for v_subj(level0).96
# Could not generate output statistics for v_subj(level4).40
# Could not generate output statistics for a_subj.76
# Could not generate output statistics for v_subj(level1).17
# Could not generate output statistics for t_subj.84
# Could not generate output statistics for t_subj.43
# Could not generate output statistics for v_subj(level2).18
# Could not generate output statistics for v_subj(level0).85
# Could not generate output statistics for v_subj(level0).90
# Could not generate output statistics for v_subj(level3).70
# Could not generate output statistics for v_subj(level1).11
# Could not generate output statistics for v_subj(level4).36
# Could not generate output statistics for t_subj.40
# Could not generate output statistics for v_subj(level0).61
# Could not generate output statistics for v_subj(level2).85
# Could not generate output statistics for v_subj(level0).58
# Could not generate output statistics for v_subj(level4).96
# Could not generate output statistics for v_subj(level1).17
# Could not generate output statistics for a_subj.46
# Could not generate output statistics for v_subj(level4).34
# Could not generate output statistics for v_subj(level0).61
# Could not generate output statistics for v_subj(level2).75
# Could not generate output statistics for v_subj(level4).38
# Could not generate output statistics for v_subj(level1).14
# Could not generate output statistics for v_subj(level4).39
# Could not generate output statistics for a_subj.93
# Could not generate output statistics for a_subj.93
# Could not generate output statistics for t_subj.82
# Could not generate output statistics for v_subj(level3).69
# Could not generate output statistics for v_subj(level0).52
# Could not generate output statistics for v_subj(level3).64
# Could not generate output statistics for v_subj(level0).89
# Could not generate output statistics for v_subj(level0).89
# Could not generate output statistics for v_subj(level4).48
# Could not generate output statistics for t_subj.45
# Could not generate output statistics for t_subj.17
# Could not generate output statistics for a_subj.1
# Could not generate output statistics for v_subj(level0).59
# Could not generate output statistics for v_subj(level2).94
# Could not generate output statistics for a_subj.10
# Could not generate output statistics for v_subj(level0).91
# Could not generate output statistics for t_subj.81
# Could not generate output statistics for v_subj(level4).95
# Could not generate output statistics for v_subj(level3).1
# Could not generate output statistics for v_subj(level3).98
# Could not generate output statistics for a_subj.15
# Could not generate output statistics for a_subj.48
# Could not generate output statistics for v_subj(level3).2
# Could not generate output statistics for v_subj(level0).53
# Could not generate output statistics for v_subj(level0).59
# Could not generate output statistics for v_subj(level0).47
# Could not generate output statistics for a_subj.48
# Could not generate output statistics for t_subj.5
# Could not generate output statistics for a_subj.52
# Could not generate output statistics for v_subj(level4).37
# Could not generate output statistics for t_subj.16
# Could not generate output statistics for v_subj(level4).40
# Could not generate output statistics for v_subj(level2).99
# Could not generate output statistics for v_subj(level4).4
# Could not generate output statistics for v_subj(level2).76
# Could not generate output statistics for a_subj.9
# Could not generate output statistics for v_subj(level3).63
# Could not generate output statistics for t_subj.4
# Could not generate output statistics for v_subj(level0).61
# Could not generate output statistics for v_subj(level0).53
# Could not generate output statistics for t_subj.10
# Could not generate output statistics for t_subj.86
# Could not generate output statistics for v_subj(level2).23
# Could not generate output statistics for v_subj(level3).26
# Could not generate output statistics for v_subj(level4).47
# Could not generate output statistics for v_subj(level3).3
# Could not generate output statistics for a_subj.99
# Could not generate output statistics for v_subj(level0).95
# Could not generate output statistics for v_subj(level0).49
# Could not generate output statistics for v_subj(level1).47
# Could not generate output statistics for v_subj(level0).44
# Could not generate output statistics for v_subj(level1).13
# Could not generate output statistics for v_subj(level3).5
# Could not generate output statistics for v_subj(level3).97
# Could not generate output statistics for t_subj.85
# Could not generate output statistics for v_subj(level1).16
# Could not generate output statistics for v_subj(level4).17
# Could not generate output statistics for a_subj.90
# Could not generate output statistics for a_subj.78
# Could not generate output statistics for v_subj(level2).71
# Could not generate output statistics for t_std
# Could not generate output statistics for v_subj(level1).15
# Could not generate output statistics for v_subj(level4).33
# Could not generate output statistics for v_subj(level4).89
# Could not generate output statistics for t_subj.79
# Could not generate output statistics for v_subj(level0).59
# Could not generate output statistics for t_subj.6
# Could not generate output statistics for v_subj(level0).60
# Could not generate output statistics for v_subj(level0).92
# Could not generate output statistics for v_subj(level1).16
# Could not generate output statistics for a_subj.91
# Could not generate output statistics for v_subj(level2).20
# Could not generate output statistics for v_subj(level4).50
# Could not generate output statistics for v_subj(level2).54
# Could not generate output statistics for v_subj(level3).63
# Could not generate output statistics for a_subj.52
# Could not generate output statistics for v_subj(level3).74
# Could not generate output statistics for v_subj(level3).30
# Could not generate output statistics for v_subj(level2).72
# Could not generate output statistics for t_subj.27
# Could not generate output statistics for v_subj(level3).73
# Could not generate output statistics for v_subj(level4).88
# Could not generate output statistics for t_subj.32
# Could not generate output statistics for a_subj.77
# Could not generate output statistics for v_subj(level0).56
# Could not generate output statistics for a_subj.69
# Could not generate output statistics for v_subj(level0).58
# Could not generate output statistics for a_subj.22
# Could not generate output statistics for t_subj.87
# Could not generate output statistics for v_subj(level2).4
# Could not generate output statistics for v_subj(level4).37
# Could not generate output statistics for a_subj.50
# Could not generate output statistics for v_subj(level0).58
# Could not generate output statistics for v(level3)
# Could not generate output statistics for v_subj(level3).72
# Could not generate output statistics for a_subj.90
# Could not generate output statistics for v_subj(level3).40
# Could not generate output statistics for v_subj(level3).10
# Could not generate output statistics for v_subj(level4).49
# Could not generate output statistics for t_subj.79
# Could not generate output statistics for v_subj(level0).2
# Could not generate output statistics for v_subj(level0).75
# Could not generate output statistics for v_subj(level3).62
# Could not generate output statistics for v_subj(level0).94
# Could not generate output statistics for v_subj(level1).41
# Could not generate output statistics for v_subj(level3).73
# Could not generate output statistics for v_subj(level2).37
# Could not generate output statistics for v_subj(level4).35
# Could not generate output statistics for v_subj(level4).9
# Could not generate output statistics for t_subj.34
# Could not generate output statistics for v_subj(level3).72
# Could not generate output statistics for v_subj(level4).1
# Could not generate output statistics for v_subj(level2).8
# Could not generate output statistics for t_subj.9
# Could not generate output statistics for v_subj(level4).49
# Could not generate output statistics for a_subj.71
# Could not generate output statistics for a_subj.55
# Could not generate output statistics for t_subj.60
# Could not generate output statistics for v_subj(level4).36
# Could not generate output statistics for v_subj(level1).12
# Could not generate output statistics for v_subj(level3).30
# Could not generate output statistics for t_subj.18
# Could not generate output statistics for t_subj.18
# Could not generate output statistics for v_subj(level4).83
# Could not generate output statistics for a_std
# Could not generate output statistics for t_subj.84
# Could not generate output statistics for v_subj(level0).72
# Could not generate output statistics for t_subj.6
# Could not generate output statistics for v_subj(level1).96
# Could not generate output statistics for t_subj.83
# Could not generate output statistics for v_subj(level2).65
# Could not generate output statistics for a_subj.50
# Could not generate output statistics for v_subj(level4).19
# Could not generate output statistics for v_subj(level0).55
# Could not generate output statistics for v_subj(level0).41
# Could not generate output statistics for t_subj.58
# Could not generate output statistics for v_subj(level1).15
# Could not generate output statistics for v_subj(level0).68
# Could not generate output statistics for v_subj(level2).37
# Could not generate output statistics for a_subj.48
# Could not generate output statistics for v_subj(level0).60
# Could not generate output statistics for v_subj(level4).69
# Could not generate output statistics for v_subj(level3).0
# Could not generate output statistics for v_subj(level3).84
# Could not generate output statistics for v_subj(level2).0
# Could not generate output statistics for v_subj(level3).71
# Could not generate output statistics for t_subj.56
# Could not generate output statistics for a_subj.58
# Could not generate output statistics for v_subj(level3).89
# Could not generate output statistics for t_subj.41
# Could not generate output statistics for t_subj.91
# Could not generate output statistics for v_subj(level0).6
# Could not generate output statistics for v_subj(level0).83
# Could not generate output statistics for v_subj(level2).41
# Could not generate output statistics for t_subj.83
# Could not generate output statistics for v_subj(level3).9
# Could not generate output statistics for v_subj(level2).7
# Could not generate output statistics for v_subj(level3).98
# Could not generate output statistics for v_subj(level4).34
# Could not generate output statistics for v_subj(level3).86
# Could not generate output statistics for v_subj(level0).83
# Could not generate output statistics for v_subj(level3).15
# Could not generate output statistics for v_subj(level4).0
# Could not generate output statistics for v_subj(level4).20
# Could not generate output statistics for v_subj(level3).79
# Could not generate output statistics for t_subj.95
# Could not generate output statistics for v_subj(level4).48
# Could not generate output statistics for t_subj.57
# Could not generate output statistics for a_subj.95
# Could not generate output statistics for v_subj(level0).82
# Could not generate output statistics for v_subj(level4).82
# Could not generate output statistics for v_subj(level4).9
# Could not generate output statistics for v_subj(level0).81
# Could not generate output statistics for t_std
# Could not generate output statistics for t_subj.82
# Could not generate output statistics for v_subj(level2).7
# Could not generate output statistics for v_subj(level2).88
# Could not generate output statistics for t_subj.57
# Could not generate output statistics for v_subj(level4).1
# Could not generate output statistics for v_subj(level3).31
# Could not generate output statistics for v_subj(level2).73
# Could not generate output statistics for v_subj(level1).74
# Could not generate output statistics for v_subj(level2).51
# Could not generate output statistics for v_subj(level4).6
# Could not generate output statistics for v_subj(level0).53
# Could not generate output statistics for v_subj(level3).38
# Could not generate output statistics for v_subj(level2).9
# Could not generate output statistics for v_subj(level0).71
# Could not generate output statistics for v_subj(level3).5
# Could not generate output statistics for v_subj(level2).39
# Could not generate output statistics for v_subj(level1).96
# Could not generate output statistics for v_subj(level2).60
# Could not generate output statistics for a_subj.61
# Could not generate output statistics for v_subj(level1).95
# Could not generate output statistics for v_subj(level0).78
# Could not generate output statistics for a_subj.93
# Could not generate output statistics for t_subj.33
# Could not generate output statistics for v_subj(level3).6
# Could not generate output statistics for t_subj.97
# Could not generate output statistics for v_subj(level2).42
# Could not generate output statistics for v_subj(level0).40
# Could not generate output statistics for v_subj(level3).7
# Could not generate output statistics for t_subj.80
# Could not generate output statistics for v_subj(level0).67
# Could not generate output statistics for v_subj(level1).77
# Could not generate output statistics for v_subj(level0).76
# Could not generate output statistics for v_subj(level3).85
# Could not generate output statistics for v_subj(level3).29
# Could not generate output statistics for v_subj(level3).36
# Could not generate output statistics for v_subj(level1).71
# Could not generate output statistics for v_subj(level1).99
# Could not generate output statistics for v_subj(level3).9
# ...
# Could not generate output statistics for t_subj.51
# Could not generate output statistics for v_subj(level2).55
# Could not generate output statistics for v_subj(level4).79
# Could not generate output statistics for v_subj(level3).33
# Could not generate output statistics for v_subj(level4).78
# Could not generate output statistics for v_subj(level1).13
# Could not generate output statistics for a_subj.92
# Could not generate output statistics for v_subj(level0).31
# Could not generate output statistics for v_subj(level3).25
# Could not generate output statistics for t_subj.0
# Could not generate output statistics for t_subj.75
# Could not generate output statistics for v_subj(level3).72
# Could not generate output statistics for v_subj(level4).51
# Could not generate output statistics for v_subj(level2).67
# Could not generate output statistics for v_subj(level0).25
# Could not generate output statistics for v_subj(level1).26
# Could not generate output statistics for v_subj(level2).71
# Could not generate output statistics for t_subj.64
# Could not generate output statistics for a_subj.20
# Could not generate output statistics for a_subj.8
# Could not generate output statistics for v_subj(level3).55
# Could not generate output statistics for v_subj(level3).28
# Could not generate output statistics for v_subj(level4).27
# Could not generate output statistics for v_subj(level0).32
# Could not generate output statistics for v_subj(level0).34
# Could not generate output statistics for a_subj.81
# Could not generate output statistics for v_subj(level2).27
# Could not generate output statistics for v_subj(level3).56
# Could not generate output statistics for v_subj(level3).4
# Could not generate output statistics for v_subj(level4).80
# Could not generate output statistics for t_subj.25
# Could not generate output statistics for v_subj(level0).40
# Could not generate output statistics for v_subj(level2).39
# Could not generate output statistics for v_subj(level0).16
# Could not generate output statistics for t_subj.84
# Could not generate output statistics for v_subj(level3).40
# Could not generate output statistics for v_subj(level2).74
# Could not generate output statistics for v_subj(level1).91
# Could not generate output statistics for t_subj.1
# Could not generate output statistics for v_subj(level3).61
# Could not generate output statistics for v_subj(level2).79
# Could not generate output statistics for a_subj.14
# Could not generate output statistics for v_subj(level1).91
# Could not generate output statistics for t_subj.67
# Could not generate output statistics for a_subj.32
# Could not generate output statistics for a_subj.23
# Could not generate output statistics for v_subj(level4).21
# Could not generate output statistics for v_subj(level1).89
# Could not generate output statistics for v_subj(level4).24
# Could not generate output statistics for v_subj(level0).31
# Could not generate output statistics for v_subj(level4).14
# Could not generate output statistics for v_subj(level1).4
# Could not generate output statistics for v(level2)
# Could not generate output statistics for v_subj(level0).98
# Could not generate output statistics for a_subj.30
# Could not generate output statistics for v_subj(level2).34
# Could not generate output statistics for a_subj.63
# Could not generate output statistics for a_subj.39
# Could not generate output statistics for v_subj(level3).59
# Could not generate output statistics for a_subj.11
# Could not generate output statistics for a_subj.55
# Could not generate output statistics for v_subj(level0).19
# Could not generate output statistics for v_subj(level4).58
# Could not generate output statistics for v_subj(level2).73
# Could not generate output statistics for v_subj(level0).8
# Could not generate output statistics for v_subj(level0).15
# Could not generate output statistics for a_subj.22
# Could not generate output statistics for v_subj(level1).29
# Could not generate output statistics for t_subj.16
# Could not generate output statistics for v_subj(level0).87
# Could not generate output statistics for v_subj(level2).46
# Could not generate output statistics for v_subj(level0).21
# Could not generate output statistics for a_subj.54
# Could not generate output statistics for v_subj(level1).5
# Could not generate output statistics for a_subj.67
# Could not generate output statistics for v_subj(level2).61
# Could not generate output statistics for v_subj(level1).13
# Could not generate output statistics for t_subj.47
# Could not generate output statistics for t_subj.1
# Could not generate output statistics for v_subj(level1).51
# Could not generate output statistics for v_subj(level0).14
# Could not generate output statistics for v_subj(level0).75
# Could not generate output statistics for t_subj.20
# Could not generate output statistics for v_subj(level3).32
# Could not generate output statistics for a_subj.35
# Could not generate output statistics for a_subj.17
# Could not generate output statistics for a_subj.16
# Could not generate output statistics for a_subj.46
# Could not generate output statistics for v_subj(level0).85
# Could not generate output statistics for v_subj(level2).63
# Could not generate output statistics for t_subj.21
# Could not generate output statistics for v_subj(level0).9
# Could not generate output statistics for t_subj.98
# Could not generate output statistics for a_subj.66
# Could not generate output statistics for v_subj(level4).25
# Could not generate output statistics for v_subj(level1).5
# Could not generate output statistics for v_subj(level0).74
# Could not generate output statistics for v_subj(level2).41
# Could not generate output statistics for v_subj(level0).81
# Could not generate output statistics for a_subj.10
# Could not generate output statistics for v_subj(level1).50
# Could not generate output statistics for v_subj(level2).61
# Could not generate output statistics for t_subj.23
# Could not generate output statistics for t_subj.64
# Could not generate output statistics for a_subj.63
# Could not generate output statistics for t_subj.77
# Could not generate output statistics for v_subj(level2).28
# Could not generate output statistics for v_subj(level2).32
# Could not generate output statistics for v(level1)
# Could not generate output statistics for t_subj.95
# Could not generate output statistics for v_subj(level2).74
# Could not generate output statistics for v_subj(level2).62
# Could not generate output statistics for a_subj.5
# Could not generate output statistics for t_subj.77
# Could not generate output statistics for a_subj.37
# Could not generate output statistics for t_subj.68
# Could not generate output statistics for v_subj(level2).44
# Could not generate output statistics for t_subj.98
# Could not generate output statistics for v_subj(level2).38
# Could not generate output statistics for v_subj(level4).58
# Could not generate output statistics for v_subj(level3).41
# Could not generate output statistics for v_subj(level0).94
# Could not generate output statistics for a_subj.26
# Could not generate output statistics for v_subj(level0).33
# Could not generate output statistics for v_subj(level2).63
# Could not generate output statistics for v_subj(level2).58
# Could not generate output statistics for v_subj(level4).59
# Could not generate output statistics for v_subj(level3).34
# Could not generate output statistics for v_subj(level2).35
# Could not generate output statistics for t_subj.30
# Could not generate output statistics for t_subj.80
# Could not generate output statistics for v_subj(level2).60
# Could not generate output statistics for t_subj.99
# Could not generate output statistics for a_subj.92
# Could not generate output statistics for v_subj(level2).89
# Could not generate output statistics for v_subj(level4).80
# Could not generate output statistics for a_subj.58
# Could not generate output statistics for t_subj.24
# Could not generate output statistics for v_subj(level0).38
# Could not generate output statistics for v_subj(level0).1
# Could not generate output statistics for t_subj.76
# Could not generate output statistics for v_subj(level3).42
# Could not generate output statistics for v_subj(level0).76
# Could not generate output statistics for v_subj(level3).48
# Could not generate output statistics for t_subj.62
# Could not generate output statistics for v_subj(level2).62
# Could not generate output statistics for v_subj(level4).64
# Could not generate output statistics for v_subj(level0).26
# Could not generate output statistics for v_subj(level0).30
# Could not generate output statistics for t_subj.7
# Could not generate output statistics for v_subj(level0).32
# Could not generate output statistics for v_subj(level4).21
# Could not generate output statistics for v_subj(level0).93
# Could not generate output statistics for v_subj(level3).57
# Could not generate output statistics for v_subj(level3).34
# Could not generate output statistics for a_subj.6
# Could not generate output statistics for v_subj(level3).7
# Could not generate output statistics for a_subj.21
# Could not generate output statistics for v_subj(level2).92
# Could not generate output statistics for v_subj(level4).63
# Could not generate output statistics for v_subj(level4).54
# Could not generate output statistics for v_subj(level4).65
# Could not generate output statistics for t_subj.19
# Could not generate output statistics for t_subj.93
# Could not generate output statistics for t_subj.68
# Could not generate output statistics for v_subj(level4).35
# Could not generate output statistics for v_subj(level0).22
# Could not generate output statistics for a_subj.2
# Could not generate output statistics for v_subj(level0).95
# Could not generate output statistics for a_subj.79
# Could not generate output statistics for v_subj(level3).44
# Could not generate output statistics for v_subj(level3).62
# Could not generate output statistics for t_subj.4
# Could not generate output statistics for t_subj.6
# Could not generate output statistics for v_subj(level2).59
# Could not generate output statistics for t_subj.17
# Could not generate output statistics for a_subj.3
# Could not generate output statistics for v_subj(level3).40
# Could not generate output statistics for v_subj(level3).31
# Could not generate output statistics for a_subj.61
# Could not generate output statistics for a_subj.66
# Could not generate output statistics for v_subj(level2).72
# Could not generate output statistics for a_subj.65
# Could not generate output statistics for v_subj(level3).60
# Could not generate output statistics for v_subj(level0).33
# Could not generate output statistics for v_subj(level2).73
# Could not generate output statistics for v_subj(level3).49
# Could not generate output statistics for v_subj(level3).41
# Could not generate output statistics for v_subj(level2).29
# Could not generate output statistics for v_subj(level4).46
# Could not generate output statistics for v_subj(level2).59
# Could not generate output statistics for v_subj(level4).63
# Could not generate output statistics for v_subj(level2).69
# Could not generate output statistics for v_subj(level3).64
# Could not generate output statistics for t_subj.71
# Could not generate output statistics for v_subj(level0).4
# Could not generate output statistics for v_subj(level4).55
# Could not generate output statistics for v_subj(level0).21
# Could not generate output statistics for v_subj(level0).96
# Could not generate output statistics for v_subj(level2).80
# Could not generate output statistics for a_subj.59
# Could not generate output statistics for a_subj.15
# Could not generate output statistics for v_subj(level0).22
# Could not generate output statistics for v_subj(level3).36
# Could not generate output statistics for v_subj(level2).33
# Could not generate output statistics for v_subj(level4).64
# Could not generate output statistics for a_subj.6
# Could not generate output statistics for t_subj.28
# Could not generate output statistics for a_subj.40
# Could not generate output statistics for a_subj.29
# Could not generate output statistics for v_subj(level4).26
# Could not generate output statistics for a_subj.64
# Could not generate output statistics for t_subj.99
# Could not generate output statistics for v_subj(level0).95
# Could not generate output statistics for a_subj.41
# Could not generate output statistics for v_subj(level3).36
# Could not generate output statistics for a_subj.0
# Could not generate output statistics for v_subj(level4).47
# Could not generate output statistics for v_subj(level4).64
# Could not generate output statistics for v_subj(level3).65
# Could not generate output statistics for t_subj.29
# Could not generate output statistics for v_subj(level4).65
# Could not generate output statistics for t_subj.78
# Could not generate output statistics for v_subj(level4).27
# Could not generate output statistics for t_subj.96
# Could not generate output statistics for a_subj.44
# Could not generate output statistics for t_subj.81
# Could not generate output statistics for t_subj.6
# Could not generate output statistics for t_subj.95
# Could not generate output statistics for v_subj(level3).61
# Could not generate output statistics for t_subj.77
# Could not generate output statistics for a_subj.16
# Could not generate output statistics for a_subj.6
# Could not generate output statistics for t_subj.81
# Could not generate output statistics for a_subj.29
# Could not generate output statistics for t_subj.17
# Could not generate output statistics for t_subj.28
# Could not generate output statistics for v_subj(level3).4
# Could not generate output statistics for a_subj.1
# Could not generate output statistics for v_subj(level3).62
# Could not generate output statistics for a_subj.25
# Could not generate output statistics for a_subj.83
# Could not generate output statistics for v_subj(level0).92
# Could not generate output statistics for v_subj(level3).38
# Could not generate output statistics for v_subj(level3).45
# Could not generate output statistics for t_subj.63
# Could not generate output statistics for v_subj(level3).39
# Could not generate output statistics for v_subj(level0).30
# Could not generate output statistics for v_subj(level4).34
# Could not generate output statistics for v_subj(level4).33
# Could not generate output statistics for t_subj.62
# Could not generate output statistics for t_subj.13
# Could not generate output statistics for v_subj(level3).61
# Could not generate output statistics for v_subj(level3).60
# Could not generate output statistics for v_subj(level4).63
# Could not generate output statistics for v_subj(level4).62
# Could not generate output statistics for v(level2)
# Could not generate output statistics for a_subj.21
# Could not generate output statistics for v_subj(level4).66
# Could not generate output statistics for v_subj(level4).65
# Could not generate output statistics for a_std
# Could not generate output statistics for t_subj.94
# Could not generate output statistics for a_subj.18
# Could not generate output statistics for v_subj(level0).37
# Could not generate output statistics for v_subj(level0).97
# Could not generate output statistics for t_std
# Could not generate output statistics for t_subj.19
# Could not generate output statistics for v_subj(level0).31
# Could not generate output statistics for a_subj.28
# Could not generate output statistics for v_subj(level3).59
# Could not generate output statistics for a_subj.80
# Could not generate output statistics for a_subj.62
# Could not generate output statistics for v_subj(level0).2
# Could not generate output statistics for v_subj(level0).83
# Could not generate output statistics for v_subj(level3).60
# Could not generate output statistics for v_std
# Could not generate output statistics for v_subj(level2).74
# Could not generate output statistics for t_subj.18
# Could not generate output statistics for v_subj(level3).56
# Could not generate output statistics for t_subj.76
# Could not generate output statistics for v_subj(level0).18
# Could not generate output statistics for v_subj(level3).57
#  [-------          18%                  ] 185 of 1000 complete in 290.6 secHalting at iteration  184  of  1000
# Halting at iteration  189  of  1000
# Halting at iteration  181  of  1000
# Halting at iteration  187  of  1000
#  [--                7%                  ] 73 of 1000 complete in 114.8 sec

# %%
np.savez("gen_data", gen_data)
np.savez("power_fitting_par100", output)
